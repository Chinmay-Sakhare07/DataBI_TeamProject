-- %%
SELECT * FROM dbw_chinook_team.chinook_gold.dim_customer
WHERE customer_id IN (7,32);

-- %%
-- See if the connection catalog is accessible at all
SHOW TABLES IN chinook_sql_conn_catalog.chinook;
