-- %%
%python

df = spark.sql("""
SELECT
    *
FROM dbw_chinook_team.chinook_gold.fact_sales
-- ORDER BY total_revenue DESC
-- LIMIT 10
""")

display(df)

-- %%
select * from dbw_chinook_team.chinook_gold.dim_customer;

-- %%
select * from dbw_chinook_team.chinook_gold.fact_sales;

-- %%
select * from dbw_chinook_team.chinook_gold.fact_sales

-- %%
Select * from dbw_chinook_team.chinook_gold.dim_customer where customer_id in (74,40);

-- %%
SELECT count(*) from dbw_chinook_team.chinook_gold.dim_customer;

-- %%
SELECT table_name, file_location, source_row_count, execution_time
FROM dbw_chinook_team.chinook_bronze.pipeline_execution_log
WHERE table_name = 'Customer'
ORDER BY execution_time DESC;

-- %%
SELECT COUNT(*) FROM dbw_chinook_team.chinook_bronze.customer;

-- %%
SELECT COUNT(*) FROM dbw_chinook_team.chinook_silver.customer;

-- %%
SELECT COUNT(*) FROM dbw_chinook_team.chinook_gold.dim_customer 
WHERE is_current = true;

-- %%
SELECT * FROM dbw_chinook_team.chinook_gold.dim_customer
WHERE customer_id IN (7,32);
