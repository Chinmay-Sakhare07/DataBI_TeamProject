# %%
df = spark.sql("""
SELECT
  customer_key,
  customer_name,
  country,
  city,
  total_revenue,
  total_invoices,
  total_line_items,
  avg_order_value,
  max_order_value,
  min_order_value
FROM dbw_chinook_team.chinook_gold.fact_sales_customer_agg
ORDER BY total_revenue DESC
LIMIT 10
""")

display(df)
